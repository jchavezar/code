# %% [markdown]
# ## Define Variables

# %%
PROJECT_ID = 'jchavezar-demo'
REGION = 'us-central1'
PIPELINE_ROOT_PATH = 'gs://vtx-root-path'
DATASET = 'demos'
DEPLOY_IMAGE = "us-docker.pkg.dev/vertex-ai/prediction/tf2-cpu.2-5:latest"
MODEL_DIR = 'gs://vtx-models/bqmodel'

# %% [markdown]
# ## Queries

# %%
### Create returning_users table
query_return = """
WITH
  firstlasttouch AS (
  SELECT
    user_pseudo_id,
    MIN(event_timestamp) AS user_first_engagement,
    MAX(event_timestamp) AS user_last_engagement
  FROM
    `firebase-public-project.analytics_153293282.events_*`
  WHERE
    event_name='user_engagement'
  GROUP BY
    user_pseudo_id )
SELECT
  user_pseudo_id,
  user_first_engagement,
  user_last_engagement,
  EXTRACT(MONTH
  FROM
    TIMESTAMP_MICROS(user_first_engagement)) AS month,
  EXTRACT(DAYOFYEAR
  FROM
    TIMESTAMP_MICROS(user_first_engagement)) AS julianday,
  EXTRACT(DAYOFWEEK
  FROM
    TIMESTAMP_MICROS(user_first_engagement)) AS dayofweek,
  #add 24 hr to user's first touch
  (user_first_engagement + 86400000000) AS ts_24hr_after_first_engagement,
  #churned = 1 if last_touch within 24 hr of app installation, else 0
IF
  (user_last_engagement < (user_first_engagement + 86400000000), 1, 0 ) AS churned,
  #bounced = 1 if last_touch within 10 min, else 0
IF
  (user_last_engagement <= (user_first_engagement + 600000000), 1, 0 ) AS bounced,
FROM
  firstlasttouch
GROUP BY
  1,
  2,
  3
"""

# %%
## Create user demographics table

query_demographics = """
WITH first_values AS (
      SELECT
          user_pseudo_id,
          geo.country as country,
          device.operating_system as operating_system,
          device.language as language,
          ROW_NUMBER() OVER (PARTITION BY user_pseudo_id ORDER BY event_timestamp DESC) AS row_num
      FROM `firebase-public-project.analytics_153293282.events_*`
      WHERE event_name='user_engagement'
      )
  SELECT * EXCEPT (row_num)
  FROM first_values
  WHERE row_num = 1
"""

# %%
## Create user aggregate behavior

query_user_agg = """
WITH
  events_first24hr AS (
    #select user data only from first 24 hr of using the app
  SELECT
    e.*
  FROM
    `firebase-public-project.analytics_153293282.events_*` e
  JOIN
    bqmlga4.returningusers r
  ON
    e.user_pseudo_id = r.user_pseudo_id
  WHERE
    e.event_timestamp <= r.ts_24hr_after_first_engagement )
SELECT
  user_pseudo_id,
  SUM(IF(event_name = 'user_engagement', 1, 0)) AS cnt_user_engagement,
  SUM(IF(event_name = 'level_start_quickplay', 1, 0)) AS cnt_level_start_quickplay,
  SUM(IF(event_name = 'level_end_quickplay', 1, 0)) AS cnt_level_end_quickplay,
  SUM(IF(event_name = 'level_complete_quickplay', 1, 0)) AS cnt_level_complete_quickplay,
  SUM(IF(event_name = 'level_reset_quickplay', 1, 0)) AS cnt_level_reset_quickplay,
  SUM(IF(event_name = 'post_score', 1, 0)) AS cnt_post_score,
  SUM(IF(event_name = 'spend_virtual_currency', 1, 0)) AS cnt_spend_virtual_currency,
  SUM(IF(event_name = 'ad_reward', 1, 0)) AS cnt_ad_reward,
  SUM(IF(event_name = 'challenge_a_friend', 1, 0)) AS cnt_challenge_a_friend,
  SUM(IF(event_name = 'completed_5_levels', 1, 0)) AS cnt_completed_5_levels,
  SUM(IF(event_name = 'use_extra_steps', 1, 0)) AS cnt_use_extra_steps,
FROM
  events_first24hr
GROUP BY
  1
"""

# %%
## Join and Create Train Dataset

query_dataset_train = f"""
  SELECT
    dem.*,
    IFNULL(beh.cnt_user_engagement, 0) AS cnt_user_engagement,
    IFNULL(beh.cnt_level_start_quickplay, 0) AS cnt_level_start_quickplay,
    IFNULL(beh.cnt_level_end_quickplay, 0) AS cnt_level_end_quickplay,
    IFNULL(beh.cnt_level_complete_quickplay, 0) AS cnt_level_complete_quickplay,
    IFNULL(beh.cnt_level_reset_quickplay, 0) AS cnt_level_reset_quickplay,
    IFNULL(beh.cnt_post_score, 0) AS cnt_post_score,
    IFNULL(beh.cnt_spend_virtual_currency, 0) AS cnt_spend_virtual_currency,
    IFNULL(beh.cnt_ad_reward, 0) AS cnt_ad_reward,
    IFNULL(beh.cnt_challenge_a_friend, 0) AS cnt_challenge_a_friend,
    IFNULL(beh.cnt_completed_5_levels, 0) AS cnt_completed_5_levels,
    IFNULL(beh.cnt_use_extra_steps, 0) AS cnt_use_extra_steps,
    ret.user_first_engagement,
    ret.month,
    ret.julianday,
    ret.dayofweek,
    ret.churned
  FROM
    {DATASET}.returningusers ret
  LEFT OUTER JOIN
    {DATASET}.user_demographics dem
  ON 
    ret.user_pseudo_id = dem.user_pseudo_id
  LEFT OUTER JOIN 
    {DATASET}.user_aggregate_behavior beh
  ON
    ret.user_pseudo_id = beh.user_pseudo_id
  WHERE ret.bounced = 0
"""

# %%
## Model Query

create_model_query = f"""

CREATE OR REPLACE MODEL {DATASET}.churn_logreg

OPTIONS(
  MODEL_TYPE='LOGISTIC_REG',
  INPUT_LABEL_COLS=['churned'],
  ENABLE_GLOBAL_EXPLAIN=TRUE
) AS

SELECT
  *
FROM
  {DATASET}.train
  
"""

# %% [markdown]
# ## Create Pipeline and Components

# %%
from kfp.v2.dsl import pipeline
from kfp.v2.components import importer_node
from google_cloud_pipeline_components.types import artifact_types
from google_cloud_pipeline_components.v1.model import ModelUploadOp
from google_cloud_pipeline_components.v1.bigquery import BigqueryCreateModelJobOp, BigqueryQueryJobOp, BigqueryEvaluateModelJobOp, BigqueryPredictModelJobOp, BigqueryExportModelJobOp

@pipeline(name='bqml-mm')
def pipeline(
    project_id: str,
    location: str,
    artifact_uri: str
):
    returning_users_table = BigqueryQueryJobOp(
        project=project_id,
        location=location,
        query=query_return,
        job_configuration_query={
            "destination_table": {
                "project_id": PROJECT_ID,
                "dataset_id": DATASET,
                "table_id": "returningusers",
            },
            "write_disposition": "WRITE_TRUNCATE"
        }
    ).set_display_name('returningusers')
    query_demographics_table = BigqueryQueryJobOp(
        project=project_id,
        location=location,
        query=query_demographics,
        job_configuration_query={
            "destination_table": {
                "project_id": PROJECT_ID,
                "dataset_id": DATASET,
                "table_id": "user_demographics",
            "write_disposition": "WRITE_TRUNCATE"
            },
            "write_disposition": "WRITE_TRUNCATE"
        }
    )
    user_aggregate_behavior_table = BigqueryQueryJobOp(
        project=project_id,
        location=location,
        query=query_user_agg,
        job_configuration_query={
            "destination_table": {
                "project_id": PROJECT_ID,
                "dataset_id": DATASET,
                "table_id": "user_aggregate_behavior",
            },
            "write_disposition": "WRITE_TRUNCATE"        
        }
    ).set_display_name('user_aggregate_behavior')
    
    # Here we create the train dataset for BigQuery ML
    
    query_dataset_train_table = BigqueryQueryJobOp(
        project=project_id,
        location=location,
        query=query_dataset_train,
        job_configuration_query={
            "destination_table": {
                "project_id": PROJECT_ID,
                "dataset_id": DATASET,
                "table_id": "train",
            },
            "write_disposition": "WRITE_TRUNCATE"
        }
    ).set_display_name('query_dataset_train').after(returning_users_table, query_demographics_table, user_aggregate_behavior_table)
    
    # We train the model
    
    create_model_query_job = BigqueryCreateModelJobOp(
        project=project_id,
        location=location,
        query=create_model_query,
    ).after(query_dataset_train_table)
    
    # Evaluate it
    
    _ = BigqueryEvaluateModelJobOp(
        project=PROJECT_ID, location="US", model=create_model_query_job.outputs["model"]
    ).after(create_model_query_job)
    
    # Make some predictions
    
    _ = BigqueryPredictModelJobOp(
        project=project_id,
        location=location,
        model=create_model_query_job.outputs["model"],
        table_name=f"`{DATASET}.train`",
        # query_statement=f"SELECT * EXCEPT ({label}) FROM {bq_table} WHERE body_mass_g IS NOT NULL AND sex IS NOT NULL"
        job_configuration_query={
            "destinationTable": {
                "project_id": PROJECT_ID,
                "dataset_id": DATASET,
                "table_id": "results_1",
            },
            "write_disposition": "WRITE_TRUNCATE"
        },
    ).after(create_model_query_job)
    
    # Export Model to 
    
    bq_export = BigqueryExportModelJobOp(
        project=project_id,
        location=location,
        model=create_model_query_job.outputs["model"],
        model_destination_path=artifact_uri,
    ).after(create_model_query_job)

    import_unmanaged_model_task = importer_node.importer(
        artifact_uri=artifact_uri,
        artifact_class=artifact_types.UnmanagedContainerModel,
        metadata={
            "containerSpec": {
                "imageUri": DEPLOY_IMAGE,
            },
        },
    ).after(bq_export)
    
    model_upload = ModelUploadOp(
        project=project_id,
        display_name="bqml_churn_logreg",
        unmanaged_container_model=import_unmanaged_model_task.outputs["artifact"],
        #explanation_parameters=EXPLAIN_PARAMS,
        #explanation_metadata=EXPLAIN_META,
    ).after(import_unmanaged_model_task)

# %% [markdown]
# ## Compile Pipeline

# %%
from kfp.v2 import compiler
import warnings
warnings.filterwarnings('ignore')

compiler.Compiler().compile(pipeline_func=pipeline,
        package_path='bqml_mm.json')

# %% [markdown]
# ## Run Pipeline

# %%
import google.cloud.aiplatform as aip

job = aip.PipelineJob(
    display_name="bqml_mm",
    template_path="bqml_mm.json",
    pipeline_root=PIPELINE_ROOT_PATH,
    parameter_values={
        'project_id': PROJECT_ID,
        'location': 'US',
        'artifact_uri': MODEL_DIR
    },
)

#job.submit()
job.run()
# Out:
# Creating PipelineJob
# PipelineJob created. Resource name: projects/569083142710/locations/us-central1/pipelineJobs/bqml-mm-20220901153758
# To use this PipelineJob in another session:
# pipeline_job = aiplatform.PipelineJob.get('projects/569083142710/locations/us-central1/pipelineJobs/bqml-mm-20220901153758')
# View Pipeline Job:
# https://console.cloud.google.com/vertex-ai/locations/us-central1/pipelines/runs/bqml-mm-20220901153758?project=569083142710
# PipelineJob projects/569083142710/locations/us-central1/pipelineJobs/bqml-mm-20220901153758 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/569083142710/locations/us-central1/pipelineJobs/bqml-mm-20220901153758 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/569083142710/locations/us-central1/pipelineJobs/bqml-mm-20220901153758 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob projects/569083142710/locations/us-central1/pipelineJobs/bqml-mm-20220901153758 current state:
# PipelineState.PIPELINE_STATE_RUNNING
# PipelineJob run completed. Resource name: projects/569083142710/locations/us-central1/pipelineJobs/bqml-mm-20220901153758

# %% [markdown]
# ## Extracting Metadata from the Model

# %%
MODEL_PATH = "gs://mco-mm/churn"

params = {"sampled_shapley_attribution": {"path_count": 10}}
EXPLAIN_PARAMS = aiplatform.explain.ExplanationParameters(params)

builder = saved_model_metadata_builder.SavedModelMetadataBuilder(
    model_path=MODEL_PATH, outputs_to_explain=["churned_probs"]
)
EXPLAIN_META = builder.get_metadata_protobuf()

# %%
MODEL_DIR = "gs://mco-mm/churn"
MODEL_NAME = "churn"
IMAGE = "us-docker.pkg.dev/cloud-aiplatform/prediction/tf2-cpu.2-5:latest"

model = aiplatform.Model.upload(
    display_name=MODEL_NAME,
    artifact_uri=MODEL_DIR,
    serving_container_image_uri=IMAGE,
    explanation_parameters=EXPLAIN_PARAMS,
    explanation_metadata=EXPLAIN_META,
    sync=True,
)

MODEL_ID = model.resource_name.split("/")[-1]
# Out:
# Creating Model
# Create Model backing LRO: projects/569083142710/locations/us-central1/models/2461476681102131200/operations/2851258294792617984
# Model created. Resource name: projects/569083142710/locations/us-central1/models/2461476681102131200@1
# To use this Model in another session:
# model = aiplatform.Model('projects/569083142710/locations/us-central1/models/2461476681102131200@1')

# %%
endpoint = model.deploy(machine_type="n1-standard-4")
print(f"endpoint display name: {endpoint.display_name}")
print(f"endpoint resource name: {endpoint.resource_name}")
ENDPOINT = endpoint.resource_name
ENDPOINT_ID = ENDPOINT.split("/")[-1]
# Out:
# Creating Endpoint
# Create Endpoint backing LRO: projects/569083142710/locations/us-central1/endpoints/1640849580641746944/operations/4332942572197511168
# Endpoint created. Resource name: projects/569083142710/locations/us-central1/endpoints/1640849580641746944
# To use this Endpoint in another session:
# endpoint = aiplatform.Endpoint('projects/569083142710/locations/us-central1/endpoints/1640849580641746944')
# Deploying model to Endpoint : projects/569083142710/locations/us-central1/endpoints/1640849580641746944
# Deploy Endpoint model backing LRO: projects/569083142710/locations/us-central1/endpoints/1640849580641746944/operations/5280950293759000576
# Endpoint model deployed. Resource name: projects/569083142710/locations/us-central1/endpoints/1640849580641746944
# endpoint display name: churn_endpoint
# endpoint resource name: projects/569083142710/locations/us-central1/endpoints/1640849580641746944

# %% [markdown]
# ## Monitoring

# %%
USER_EMAIL = "jesusarguelles@google.com"
JOB_NAME = "churn"

LOG_SAMPLE_RATE = 0.8
MONITOR_INTERVAL = 3600
DATASET_BQ_URI = "bq://jchavezar-demo.demos.train"
TARGET = "churned"

DEFAULT_THRESHOLD_VALUE = 0.001

SKEW_THRESHOLDS = {
    "country": DEFAULT_THRESHOLD_VALUE,
    "cnt_user_engagement": DEFAULT_THRESHOLD_VALUE,
}
DRIFT_THRESHOLDS = {
    "country": DEFAULT_THRESHOLD_VALUE,
    "cnt_user_engagement": DEFAULT_THRESHOLD_VALUE,
}
ATTRIB_SKEW_THRESHOLDS = {
    "country": DEFAULT_THRESHOLD_VALUE,
    "cnt_user_engagement": DEFAULT_THRESHOLD_VALUE,
}
ATTRIB_DRIFT_THRESHOLDS = {
    "country": DEFAULT_THRESHOLD_VALUE,
    "cnt_user_engagement": DEFAULT_THRESHOLD_VALUE,
}

# %%
from google.cloud.aiplatform import model_monitoring

skew_config = model_monitoring.SkewDetectionConfig(
    data_source=DATASET_BQ_URI,
    skew_thresholds=SKEW_THRESHOLDS,
    attribute_skew_thresholds=ATTRIB_SKEW_THRESHOLDS,
    target_field=TARGET,
)

# %%
drift_config = model_monitoring.DriftDetectionConfig(
    drift_thresholds=DRIFT_THRESHOLDS,
    attribute_drift_thresholds=ATTRIB_DRIFT_THRESHOLDS,
)

explanation_config = model_monitoring.ExplanationConfig()
objective_config = model_monitoring.ObjectiveConfig(
    skew_config, drift_config, explanation_config
)

# %%
from google.cloud import aiplatform

# Create sampling configuration
random_sampling = model_monitoring.RandomSampleConfig(sample_rate=LOG_SAMPLE_RATE)

# Create schedule configuration
schedule_config = model_monitoring.ScheduleConfig(monitor_interval=MONITOR_INTERVAL)

# Create alerting configuration.
emails = [USER_EMAIL]
alerting_config = model_monitoring.EmailAlertConfig(
    user_emails=emails, enable_logging=True
)

# Create the monitoring job.
job = aiplatform.ModelDeploymentMonitoringJob.create(
    display_name=JOB_NAME,
    logging_sampling_strategy=random_sampling,
    schedule_config=schedule_config,
    alert_config=alerting_config,
    objective_configs=objective_config,
    project=PROJECT_ID,
    location=REGION,
    endpoint=endpoint,
)
# Out:
# Creating ModelDeploymentMonitoringJob
# ModelDeploymentMonitoringJob created. Resource name: projects/569083142710/locations/us-central1/modelDeploymentMonitoringJobs/3277647735813046272
# To use this ModelDeploymentMonitoringJob in another session:
# mdm_job = aiplatform.ModelDeploymentMonitoringJob('projects/569083142710/locations/us-central1/modelDeploymentMonitoringJobs/3277647735813046272')
# View Model Deployment Monitoring Job:
# https://console.cloud.google.com/ai/platform/locations/us-central1/model-deployment-monitoring/3277647735813046272?project=569083142710

# %%
DEFAULT_INPUT = {
    "cnt_ad_reward": 0,
    "cnt_challenge_a_friend": 0,
    "cnt_completed_5_levels": 1,
    "cnt_level_complete_quickplay": 3,
    "cnt_level_end_quickplay": 5,
    "cnt_level_reset_quickplay": 2,
    "cnt_level_start_quickplay": 6,
    "cnt_post_score": 34,
    "cnt_spend_virtual_currency": 0,
    "cnt_use_extra_steps": 0,
    "cnt_user_engagement": 120,
    "country": "Denmark",
    "dayofweek": 3,
    "julianday": 254,
    "language": "da-dk",
    "month": 9,
    "operating_system": "IOS",
    "user_pseudo_id": "104B0770BAE16E8B53DF330C95881893",
}

# %%
# Run a prediction request to generate schema, if necessary.
try:
    _ = endpoint.predict([DEFAULT_INPUT])
    print("prediction succeeded")
except Exception as e:
    print(f"prediction failed: {e}")
# Out:
# prediction succeeded

# %%
# !gsutil cat gs://cloud-ai-platform-9b627e36-89f4-4b8c-bf59-1e00936392b5/model_monitoring/job-4451685361231331328/batch_prediction_output/training/2694564350097620992/batch_prediction_output/prediction-churn-2022_06_14T07_07_01_207Z/explanation.results-00006-of-00007
# Out:
# {"instance": {"user_pseudo_id": "434B79A24E73A32E488354A1AAD98495", "country": "United States", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 46, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 4, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 8, "julianday": 220, "dayofweek": 4}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["1"], "churned_probs": [0.8249296206859882, 0.17507037931401181]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.8249296206859882, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 1.1102230246251566e-17, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": -1.1102230246251566e-17, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0002990852485152622, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": 0.007091913843882069, "country": 0.062208892437959316, "dayofweek": -0.0012040792605202701, "julianday": 0.2670913355873007, "language": -0.0361951541272743, "month": 0.20861686782781272, "operating_system": -0.04419986627653762, "user_pseudo_id": 0.34131232268329315}, "approximationError": 0.018070928608340826}]}}
# {"instance": {"user_pseudo_id": "E0F1DC58BE9661A3DFD9C3228B179C29", "country": "Singapore", "operating_system": "ANDROID", "language": "en-gb", "cnt_user_engagement": 162, "cnt_level_start_quickplay": 2, "cnt_level_end_quickplay": 1, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 30, "cnt_spend_virtual_currency": 2, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 1, "cnt_use_extra_steps": 2, "month": 8, "julianday": 216, "dayofweek": 7}, "prediction": {"churned_probs": [0.8223837260720044, 0.17761627392799562], "churned_values": ["1", "0"], "predicted_churned": ["1"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.8223837260720045, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.03415940153599714, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": -5.767235695842837e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 6.110802947818794e-05, "cnt_post_score": 0.002313122337225924, "cnt_spend_virtual_currency": 0.00731417272214091, "cnt_use_extra_steps": 0.006449706266505628, "cnt_user_engagement": 0.023892987499940066, "country": 0.040607953464542754, "dayofweek": -0.0020054050061974705, "julianday": 0.2679450955170969, "language": -0.04288288540456701, "month": 0.20551968719860172, "operating_system": -0.04687503749914758, "user_pseudo_id": 0.30603318904578863}, "approximationError": 0.018284388874190965}]}}
# {"instance": {"user_pseudo_id": "8BB00DF4D414F28B66E557C9846232AA", "country": "United States", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 5, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 170, "dayofweek": 3}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.05230485942381251, 0.9476951405761875]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9476951405761875, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.00011347374278587452, "country": -0.02546920008125515, "dayofweek": 0.00029783017237130507, "julianday": -0.0348636379138189, "language": 0.01757489851520464, "month": -0.031060896171753317, "operating_system": 0.0166279889454126, "user_pseudo_id": 0.024609933574369424}, "approximationError": 0.020661441668542252}]}}
# {"instance": {"user_pseudo_id": "0FB030B897D1A6360CCD8CCBF9031755", "country": "Japan", "operating_system": "ANDROID", "language": "ja-jp", "cnt_user_engagement": 37, "cnt_level_start_quickplay": 1, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 13, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 1, "cnt_use_extra_steps": 0, "month": 8, "julianday": 222, "dayofweek": 6}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["1"], "churned_probs": [0.8313902908539423, 0.16860970914605766]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.8313902908539426, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.03371197659273525, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 3.088309516769971e-05, "cnt_post_score": 0.0009991255342611193, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": 0.005574488059688583, "country": 0.06529002919892936, "dayofweek": -0.0017662690470940337, "julianday": 0.26653293867221584, "language": -0.041386007758503346, "month": 0.21043908617532026, "operating_system": -0.04616689172351094, "user_pseudo_id": 0.31822262933317563}, "approximationError": 0.018640560681501623}]}}
# {"instance": {"user_pseudo_id": "8E2768C381113D72B39CCE7961BE5481", "country": "Mexico", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 311, "cnt_level_start_quickplay": 32, "cnt_level_end_quickplay": 15, "cnt_level_complete_quickplay": 2, "cnt_level_reset_quickplay": 12, "cnt_post_score": 30, "cnt_spend_virtual_currency": 5, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 1, "cnt_use_extra_steps": 5, "month": 7, "julianday": 192, "dayofweek": 4}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.1092406864306329, 0.8907593135693671]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.8907593135693671, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": -0.013575238597227424, "cnt_level_complete_quickplay": 4.184586613691366e-05, "cnt_level_end_quickplay": 0.0004286105952809205, "cnt_level_reset_quickplay": -0.0008581921873133336, "cnt_level_start_quickplay": -0.0005773908133544836, "cnt_post_score": -0.0016383425821691721, "cnt_spend_virtual_currency": -0.013102151672118211, "cnt_use_extra_steps": -0.006965357254695182, "cnt_user_engagement": -0.010071484006358511, "country": -0.05128218612112301, "dayofweek": 0.000508188870621451, "julianday": -0.06146600669284481, "language": 0.02973580619216949, "month": -0.053890972140627234, "operating_system": 0.03210942746682819, "user_pseudo_id": 0.061271059367718705}, "approximationError": 0.02871592205402945}]}}
# {"instance": {"user_pseudo_id": "64BB7DFAE772A77F70FB63373D0808F5", "country": "United States", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 6, "cnt_level_start_quickplay": 1, "cnt_level_end_quickplay": 1, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 1, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 1, "month": 7, "julianday": 185, "dayofweek": 4}, "prediction": {"churned_probs": [0.06335526112176415, 0.9366447388782358], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9366447388782358, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 1.9682628368911102e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -1.2000388514432636e-05, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": -0.0016564095802031665, "cnt_use_extra_steps": -0.000884165423347616, "cnt_user_engagement": -0.00014447602744267486, "country": -0.028360173284395707, "dayofweek": 0.0004138475209998882, "julianday": -0.042796428669560016, "language": 0.020134075423361743, "month": -0.03924060407570058, "operating_system": 0.019391153063049883, "user_pseudo_id": 0.02968854041317681}, "approximationError": 0.022304544247516513}]}}
# {"instance": {"user_pseudo_id": "0CE0108DD168AC70E11C9DD96C122956", "country": "Chile", "operating_system": "ANDROID", "language": "es-ar", "cnt_user_engagement": 41, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 6, "cnt_spend_virtual_currency": 2, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 1, "cnt_use_extra_steps": 2, "month": 7, "julianday": 211, "dayofweek": 2}, "prediction": {"churned_probs": [0.09829933763861548, 0.9017006623613846], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9017006623613845, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": -0.0106025661318919, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": -0.0002465198742071406, "cnt_spend_virtual_currency": -0.004632014214938018, "cnt_use_extra_steps": -0.002151981730904473, "cnt_user_engagement": -0.0010628618835202054, "country": -0.02025388928369056, "dayofweek": 0.00021352643221537183, "julianday": -0.054974331534167156, "language": -0.02047879045644969, "month": -0.03831498282640382, "operating_system": 0.026525171517551693, "user_pseudo_id": 0.04758820506934756}, "approximationError": 0.026976020206150024}]}}
# {"instance": {"user_pseudo_id": "357C6FA6170499AAC6FDC8A171A67C10", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 3, "cnt_level_start_quickplay": 1, "cnt_level_end_quickplay": 1, "cnt_level_complete_quickplay": 1, "cnt_level_reset_quickplay": 0, "cnt_post_score": 1, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 168, "dayofweek": 1}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.1357471163285767, 0.8642528836714233]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.8642528836714233, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 2.0243028183841717e-05, "cnt_level_end_quickplay": 2.7045499654021475e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -2.02539705786986e-05, "cnt_post_score": -5.262941512720332e-05, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.00014194190932486083, "country": -0.03899054283654986, "dayofweek": 0.00015702359616049933, "julianday": -0.0839395660378833, "language": 0.031096810657305095, "month": -0.05363807421939008, "operating_system": 0.029643072000531023, "user_pseudo_id": 0.0}, "approximationError": 0.019849675815287984}]}}
# {"instance": {"user_pseudo_id": "4B0AFFB47CC81EDE5DC4F902B85F0E38", "country": "Canada", "operating_system": "IOS", "language": "fr-ca", "cnt_user_engagement": 10, "cnt_level_start_quickplay": 3, "cnt_level_end_quickplay": 3, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 179, "dayofweek": 5}, "prediction": {"churned_probs": [0.04855692216830885, 0.9514430778316911], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9514430778316911, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 4.9283639181307846e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -2.8819773955990337e-05, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.00022222216986269582, "country": -0.024313234574080987, "dayofweek": 0.0004804755039296005, "julianday": -0.035337216341598074, "language": 0.024541179162284134, "month": -0.030755638817275544, "operating_system": 0.014959595005979343, "user_pseudo_id": 0.021977978918647233}, "approximationError": 0.021166945283107527}]}}
# {"instance": {"user_pseudo_id": "4DBEB5B9A21E6DBC6F52F17C4B761B4A", "country": "United Kingdom", "operating_system": "ANDROID", "language": "en-gb", "cnt_user_engagement": 6, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 1, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 7, "julianday": 207, "dayofweek": 5}, "prediction": {"churned_probs": [0.0582143647600723, 0.9417856352399276], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9417856352399278, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": -3.114907992765037e-05, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.00013384521446779818, "country": -0.020528720406201306, "dayofweek": 0.00047038903136040753, "julianday": -0.043766471124564776, "language": 0.020698951205209905, "month": -0.03636099340187193, "operating_system": 0.016858302387797085, "user_pseudo_id": 0.024487474564151013}, "approximationError": 0.022264005151890625}]}}
# {"instance": {"user_pseudo_id": "AFA456AC9C8C730EDAA31D4ADB476ADE", "country": "United States", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 1, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 174, "dayofweek": 7}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.05255048595626084, 0.9474495140437391]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9474495140437391, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -2.261173542765782e-05, "country": -0.025503664614636202, "dayofweek": 0.0006948457273334929, "julianday": -0.035614528343339, "language": 0.017523143210013782, "month": -0.03077828351879299, "operating_system": 0.01657298317001039, "user_pseudo_id": 0.024485932870134498}, "approximationError": 0.0206677832655656}]}}
# {"instance": {"user_pseudo_id": "7C14D1AD9F8CAC89B3ECC681C500D50D", "country": "United States", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 51, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 13, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 1, "cnt_use_extra_steps": 0, "month": 8, "julianday": 225, "dayofweek": 2}, "prediction": {"churned_probs": [0.8366334196950054, 0.16336658030499462], "churned_values": ["1", "0"], "predicted_churned": ["1"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.8366334196950054, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.03347504797104196, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0009885286895491175, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": 0.0076283370925288255, "country": 0.06178747177514073, "dayofweek": -0.0005818876427473002, "julianday": 0.26903897056948356, "language": -0.03774434825393132, "month": 0.2097523183691336, "operating_system": -0.04575355000297011, "user_pseudo_id": 0.31813422840621913}, "approximationError": 0.01854457621020847}]}}
# {"instance": {"user_pseudo_id": "6AE69BD54E326143C501A49A4CCD0CBB", "country": "United States", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 13, "cnt_level_start_quickplay": 2, "cnt_level_end_quickplay": 2, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 1, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 7, "julianday": 186, "dayofweek": 5}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.06181247822570811, 0.9381875217742919]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9381875217742919, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 3.897346798580337e-05, "cnt_level_reset_quickplay": -5.2880109629382946e-05, "cnt_level_start_quickplay": -2.3682369910549282e-05, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.0003093789450167472, "country": -0.027961798210972156, "dayofweek": 0.0005179332619560606, "julianday": -0.042573866505182134, "language": 0.01997292594109241, "month": -0.03879869678501195, "operating_system": 0.018801120767723757, "user_pseudo_id": 0.02848517398281396}, "approximationError": 0.022308731191216055}]}}
# {"instance": {"user_pseudo_id": "66104DA637179E352421E425EF3E1C92", "country": "Saudi Arabia", "operating_system": "IOS", "language": "ar-sa", "cnt_user_engagement": 51, "cnt_level_start_quickplay": 5, "cnt_level_end_quickplay": 5, "cnt_level_complete_quickplay": 1, "cnt_level_reset_quickplay": 0, "cnt_post_score": 8, "cnt_spend_virtual_currency": 1, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 1, "cnt_use_extra_steps": 1, "month": 9, "julianday": 268, "dayofweek": 3}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["1"], "churned_probs": [0.864661976545628, 0.13533802345437196]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.864661976545628, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.03158172624819543, "cnt_level_complete_quickplay": -5.09369477039813e-05, "cnt_level_end_quickplay": -0.0002717548369564504, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0001527329208210193, "cnt_post_score": 0.0005984722436896052, "cnt_spend_virtual_currency": 0.003266193945220812, "cnt_use_extra_steps": 0.0033591930566501, "cnt_user_engagement": 0.006802460772364696, "country": 0.062119648408602166, "dayofweek": -0.000773675136096226, "julianday": 0.30876038819560214, "language": -0.017044893791623158, "month": 0.23801718787574883, "operating_system": -0.04512421884785037, "user_pseudo_id": 0.25336114971740625}, "approximationError": 0.01834650291800444}]}}
# {"instance": {"user_pseudo_id": "08A1668F786A08C724B1F99689AAF716", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 48, "cnt_level_start_quickplay": 24, "cnt_level_end_quickplay": 10, "cnt_level_complete_quickplay": 9, "cnt_level_reset_quickplay": 13, "cnt_post_score": 9, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 8, "julianday": 215, "dayofweek": 6}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.07777218080146794, 0.922227819198532]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.922227819198532, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.00012669889178080763, "cnt_level_end_quickplay": 0.00022511550102708445, "cnt_level_reset_quickplay": -0.0007956080268355592, "cnt_level_start_quickplay": -0.0003399820706031953, "cnt_post_score": -0.00035789003780914983, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.001242072029533392, "country": -0.0312952140103673, "dayofweek": 0.0006626266815902726, "julianday": -0.05587504169937674, "language": 0.023344347865924275, "month": -0.04831445313704896, "operating_system": 0.021655535402112423, "user_pseudo_id": 0.034342058589228654}, "approximationError": 0.024110471805982706}]}}
# {"instance": {"user_pseudo_id": "BE1F4F5090933C8D1709645BCAD0AF78", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 26, "cnt_level_start_quickplay": 2, "cnt_level_end_quickplay": 2, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 7, "julianday": 183, "dayofweek": 2}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["1"], "churned_probs": [0.8039921204412709, 0.19600787955872911]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.8039921204412709, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": -2.2204460492503132e-17, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": -0.00011921167352966083, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 6.189386187545332e-05, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": 0.004199789598472203, "country": 0.06520995495568109, "dayofweek": -0.0006314849196884381, "julianday": 0.22672286525210827, "language": -0.0365018073172286, "month": 0.1817017877558493, "operating_system": -0.04416777922657102, "user_pseudo_id": 0.38760780943274514}, "approximationError": 0.017499193153998907}]}}
# {"instance": {"user_pseudo_id": "BD76EE5AD8E7D56599A9CDB72CC8C261", "country": "India", "operating_system": "ANDROID", "language": "en-gb", "cnt_user_engagement": 7, "cnt_level_start_quickplay": 1, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 7, "julianday": 200, "dayofweek": 5}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.20836682811444573, 0.7916331718855543]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.7916331718855543, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -2.699967839998596e-05, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.00042500694085592097, "country": -0.062089301725729774, "dayofweek": 0.0010068304175898436, "julianday": -0.1342334842282103, "language": 0.04503946050010608, "month": -0.0782043590316058, "operating_system": 0.04047433529421731, "user_pseudo_id": 0.0}, "approximationError": 0.02085224896237794}]}}
# {"instance": {"user_pseudo_id": "00B6D40595249C8532BCA9846389C411", "country": "India", "operating_system": "ANDROID", "language": "en-in", "cnt_user_engagement": 14, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 9, "julianday": 251, "dayofweek": 7}, "prediction": {"churned_probs": [0.42331564543277683, 0.5766843545672231], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.5766843545672231, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": -2.2204460492503132e-17, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 2.2204460492503132e-17, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.0010882646947840912, "country": -0.07908558926178273, "dayofweek": 0.0017561585383940813, "julianday": -0.2516472702373835, "language": -0.0030601548809037647, "month": -0.12843578958906202, "operating_system": 0.05815356741430231, "user_pseudo_id": 0.0}, "approximationError": 0.019335736699398066}]}}
# {"instance": {"user_pseudo_id": "F12CC3AED1B1815F6222E8395E1A0F1C", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 1, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 176, "dayofweek": 2}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.053946060547245295, 0.9460539394527547]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9460539394527547, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -2.3041709889137784e-05, "country": -0.025666007167745853, "dayofweek": 0.00020054286332436, "julianday": -0.03657507247198764, "language": 0.017788625976332663, "month": -0.031156436532290343, "operating_system": 0.016566127160070797, "user_pseudo_id": 0.024827504056497075}, "approximationError": 0.020750458965402768}]}}
# {"instance": {"user_pseudo_id": "BC1AF9C485B77D96242B88EE5085B1E5", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 3, "cnt_level_start_quickplay": 1, "cnt_level_end_quickplay": 1, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 2, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 177, "dayofweek": 3}, "prediction": {"churned_probs": [0.14172549033236906, 0.858274509667631], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.858274509667631, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 2.7356404647038703e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -2.077805996436588e-05, "cnt_post_score": -0.00010722714605910788, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.00014510705710348847, "country": -0.03963515222889746, "dayofweek": 0.0004790326054976646, "julianday": -0.09022164617997623, "language": 0.031664966336233835, "month": -0.05411865845689538, "operating_system": 0.030260026171705666, "user_pseudo_id": 0.0}, "approximationError": 0.020057001168115658}]}}
# {"instance": {"user_pseudo_id": "D37A5EC9F79C593DDB7840E9AFB3FF1F", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 26, "cnt_level_start_quickplay": 9, "cnt_level_end_quickplay": 6, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 8, "julianday": 228, "dayofweek": 5}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.08021725568125575, 0.9197827443187443]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9197827443187443, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.00013501949541341318, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -0.0001294159807011752, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.0006852604754595815, "country": -0.03169645388514308, "dayofweek": 0.000559420128096666, "julianday": -0.05989199513604922, "language": 0.02359101221090696, "month": -0.04806451584590612, "operating_system": 0.021786330619671966, "user_pseudo_id": 0.03408690590947165}, "approximationError": 0.024208054457937615}]}}
# {"instance": {"user_pseudo_id": "D8A6BDFA89F65FC9B5159A3031C33004", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 22, "cnt_level_start_quickplay": 6, "cnt_level_end_quickplay": 5, "cnt_level_complete_quickplay": 1, "cnt_level_reset_quickplay": 0, "cnt_post_score": 1, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 173, "dayofweek": 6}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.05337065713204016, 0.9466293428679599]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9466293428679599, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 1.1259009661124253e-05, "cnt_level_end_quickplay": 8.691144570351916e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -6.2132632076084e-05, "cnt_post_score": -3.019002959010475e-05, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.0005012785899793703, "country": -0.025577445329199366, "dayofweek": 0.0005953200675469672, "julianday": -0.03573238036188644, "language": 0.01771834062372992, "month": -0.031190731023107654, "operating_system": 0.016474238914379158, "user_pseudo_id": 0.024745733494335377}, "approximationError": 0.02079638171519621}]}}
# {"instance": {"user_pseudo_id": "C6F1E972D68BE8C168E02404C3B272C7", "country": "Egypt", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 2, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 8, "julianday": 222, "dayofweek": 6}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.06290681529264805, 0.9370931847073519]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.937093184707352, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -4.3608915614279375e-05, "country": -0.01585178979331605, "dayofweek": 0.0005433241003084844, "julianday": -0.04815416126734784, "language": 0.019224533213502946, "month": -0.04204729813511132, "operating_system": 0.01750437120947912, "user_pseudo_id": 0.025826117017008165}, "approximationError": 0.022785158325032997}]}}
# {"instance": {"user_pseudo_id": "E3ED6A6AA83458854791261F342BA78A", "country": "Belgium", "operating_system": "ANDROID", "language": "nl-be", "cnt_user_engagement": 60, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 20, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 1, "cnt_use_extra_steps": 0, "month": 7, "julianday": 211, "dayofweek": 2}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["1"], "churned_probs": [0.8853980136507432, 0.11460198634925678]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.8853980136507432, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.02828723236955366, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.00135670345626489, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": 0.007573647014909599, "country": 0.0813100868953016, "dayofweek": -0.0004918156501000859, "julianday": 0.22706693965584393, "language": 0.10747143731410322, "month": 0.1938656686061478, "operating_system": -0.04577392735886777, "user_pseudo_id": 0.26482373862602915}, "approximationError": 0.0206404499428076}]}}
# {"instance": {"user_pseudo_id": "15967C65E3EF3F521341D2DFD1053EA9", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 2, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 9, "julianday": 258, "dayofweek": 7}, "prediction": {"churned_probs": [0.09538580734304299, 0.904614192656957], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9046141926569571, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -5.6473194439221607e-05, "country": -0.03504438292152327, "dayofweek": 0.0008381214657668279, "julianday": -0.07469064200274156, "language": 0.026441579910198597, "month": -0.05698515259886174, "operating_system": 0.02448654919846758, "user_pseudo_id": 0.03953289552164707}, "approximationError": 0.02541521201804536}]}}
# {"instance": {"user_pseudo_id": "922B53D261E35A804BCD5689A68162EF", "country": "China", "operating_system": "IOS", "language": "zh-hans-cn", "cnt_user_engagement": 2, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 9, "julianday": 266, "dayofweek": 1}, "prediction": {"churned_probs": [0.12259508197256566, 0.8774049180274344], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.8774049180274344, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -6.54091458798689e-05, "country": -0.051747358651392836, "dayofweek": 0.00014404652023409793, "julianday": -0.08717563903383674, "language": 0.003606122378532439, "month": -0.061491527317373215, "operating_system": 0.03186286302048722, "user_pseudo_id": 0.06218012297822047}, "approximationError": 0.027565464245605905}]}}
# {"instance": {"user_pseudo_id": "8572B4BE029A37D6D73C28E42805A49F", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 11, "cnt_level_start_quickplay": 3, "cnt_level_end_quickplay": 3, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 1, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 1, "month": 8, "julianday": 233, "dayofweek": 3}, "prediction": {"churned_probs": [0.2571699699709879, 0.742830030029012], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.7428300300290122, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.00010823682178773275, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -9.210781466939544e-05, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": -0.0035247383179607184, "cnt_use_extra_steps": -0.0013670472191166017, "cnt_user_engagement": -0.0007086847737646674, "country": -0.05134173210339625, "dayofweek": 0.0006035522949801253, "julianday": -0.17208487227291297, "language": 0.04262144400775456, "month": -0.09484921287680581, "operating_system": 0.04337349500467336, "user_pseudo_id": 0.0}, "approximationError": 0.020661605661447948}]}}
# {"instance": {"user_pseudo_id": "0670A0795F7D032D0CD50FB6D0415309", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 1, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 176, "dayofweek": 2}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.14102770657062966, 0.8589722934293703]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.8589722934293704, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -4.830007325644648e-05, "country": -0.03956596758032249, "dayofweek": 0.00031898492168562774, "julianday": -0.08953585991690023, "language": 0.03161085353837807, "month": -0.05409686750627925, "operating_system": 0.03019775276762233, "user_pseudo_id": 0.0}, "approximationError": 0.020039197049598265}]}}
# {"instance": {"user_pseudo_id": "551130953A7F37F23035F9A91CA41C15", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 308, "cnt_level_start_quickplay": 121, "cnt_level_end_quickplay": 119, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 170, "dayofweek": 3}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.06037032922823907, 0.939629670771761]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.939629670771761, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0023576700258882257, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -0.001413886821286403, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.007398662277848622, "country": -0.0266838179370835, "dayofweek": 0.0002863495658601778, "julianday": -0.03714558956423937, "language": 0.020106131512716098, "month": -0.036140065839435895, "operating_system": 0.01826453935905028, "user_pseudo_id": 0.02730530546969716}, "approximationError": 0.023241615791996278}]}}
# {"instance": {"user_pseudo_id": "97E7144B7FA861C3C8DB7424D7039832", "country": "United States", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 29, "cnt_level_start_quickplay": 11, "cnt_level_end_quickplay": 4, "cnt_level_complete_quickplay": 1, "cnt_level_reset_quickplay": 3, "cnt_post_score": 3, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 7, "julianday": 183, "dayofweek": 2}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.17158860616874877, 0.8284113938312512]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.8284113938312513, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 2.3062561114239877e-05, "cnt_level_end_quickplay": 0.00012358140875354807, "cnt_level_reset_quickplay": -0.0002655577862622716, "cnt_level_start_quickplay": -0.0002655344590216657, "cnt_post_score": -0.00018540176646624217, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.0015210491014308269, "country": -0.043773279263521744, "dayofweek": 0.00034284697569348933, "julianday": -0.10718483766081674, "language": 0.035981297210257245, "month": -0.07031257801278075, "operating_system": 0.0353571464472902, "user_pseudo_id": 0.0}, "approximationError": 0.02021435817736702}]}}
# {"instance": {"user_pseudo_id": "538A5090BECB4AED98392B44DCD3C8E3", "country": "Brazil", "operating_system": "ANDROID", "language": "pt-br", "cnt_user_engagement": 1, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 168, "dayofweek": 1}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.060936049562629394, 0.9390639504373706]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9390639504373706, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -2.505400504304589e-05, "country": -0.033118385454256896, "dayofweek": 0.00011179541763350898, "julianday": -0.03821960650848248, "language": 0.013291603824237908, "month": -0.0332306166286521, "operating_system": 0.019580551634030254, "user_pseudo_id": 0.03058196487946061}, "approximationError": 0.02142775186128736}]}}
# ...
# {"instance": {"user_pseudo_id": "4F98432849F007FEDE71E2110B55C443", "country": "United Kingdom", "operating_system": "None", "language": "en-gb", "cnt_user_engagement": 9, "cnt_level_start_quickplay": 3, "cnt_level_end_quickplay": 3, "cnt_level_complete_quickplay": 2, "cnt_level_reset_quickplay": 0, "cnt_post_score": 2, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 164, "dayofweek": 4}, "prediction": {"churned_probs": [0.04476214440137771, 0.9552378555986223], "churned_values": ["1", "0"], "predicted_churned": ["0"]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9552378555986223, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 2.2204460492503132e-17, "cnt_level_complete_quickplay": 2.094556657190605e-05, "cnt_level_end_quickplay": 4.150065753407706e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -2.373547642229301e-05, "cnt_post_score": -4.908189748726865e-05, "cnt_spend_virtual_currency": 2.2204460492503132e-17, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.0001677720999569532, "country": -0.01592000041538295, "dayofweek": 0.0003405455704183602, "julianday": -0.026405099255640118, "language": 0.01470613134729013, "month": -0.025720604695399586, "operating_system": 0.0, "user_pseudo_id": 0.02832332901865413}, "approximationError": 0.019679717228994902}]}}
# {"instance": {"user_pseudo_id": "A2616A0876190B8C349DE35A9AF631B9", "country": "India", "operating_system": "ANDROID", "language": "en-us", "cnt_user_engagement": 20, "cnt_level_start_quickplay": 4, "cnt_level_end_quickplay": 3, "cnt_level_complete_quickplay": 2, "cnt_level_reset_quickplay": 0, "cnt_post_score": 2, "cnt_spend_virtual_currency": 2, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 2, "month": 9, "julianday": 245, "dayofweek": 1}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.10634538300425113, 0.8936546169957489]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.8936546169957489, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 3.6111560388829565e-05, "cnt_level_end_quickplay": 8.440636007844837e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -7.15373017591947e-05, "cnt_post_score": -0.00010102550707071777, "cnt_spend_virtual_currency": -0.0049460993013713764, "cnt_use_extra_steps": -0.0023200407760676665, "cnt_user_engagement": -0.0006218342126206756, "country": -0.04901431964874934, "dayofweek": 0.00013191606415756673, "julianday": -0.07727242459495487, "language": 0.02929161601077146, "month": -0.06304592529233752, "operating_system": 0.0293617999658053, "user_pseudo_id": 0.052050276391035835}, "approximationError": 0.026676904500976085}]}}
# {"instance": {"user_pseudo_id": "66CA5D58BEE095A3C60BE7BD3783E3CD", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 1, "cnt_level_start_quickplay": 0, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 9, "julianday": 257, "dayofweek": 6}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.09522630520247236, 0.9047736947975277]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9047736947975277, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.0, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -2.8243275480233088e-05, "country": -0.035025173483291504, "dayofweek": 0.0007183558981522342, "julianday": -0.07441483369924877, "language": 0.026439056331203047, "month": -0.05704762809311441, "operating_system": 0.024487732945400964, "user_pseudo_id": 0.03955273089546354}, "approximationError": 0.025397032139688587}]}}
# {"instance": {"user_pseudo_id": "1B8DB48C9705ACC67F6D901929B0A890", "country": "Turkey", "operating_system": "ANDROID", "language": "tr-tr", "cnt_user_engagement": 17, "cnt_level_start_quickplay": 2, "cnt_level_end_quickplay": 1, "cnt_level_complete_quickplay": 1, "cnt_level_reset_quickplay": 0, "cnt_post_score": 6, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 7, "julianday": 183, "dayofweek": 2}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.023989503957223258, 0.9760104960427768]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9760104960427768, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 2.2204460492503132e-17, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 7.021277584584595e-06, "cnt_level_end_quickplay": 1.0496449386665496e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -1.3224269525236032e-05, "cnt_post_score": -0.00011129614203844173, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.0002536812890024498, "country": -0.0012085289834770974, "dayofweek": 0.00011621701501312032, "julianday": -0.024285282774861174, "language": 0.0329790326114475, "month": -0.029609684981388783, "operating_system": 0.007477638743783798, "user_pseudo_id": 0.010810091107411468}, "approximationError": 0.022862890601973964}]}}
# {"instance": {"user_pseudo_id": "A085DABA848610B4627EC79F2342A4F4", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 6, "cnt_level_start_quickplay": 2, "cnt_level_end_quickplay": 2, "cnt_level_complete_quickplay": 2, "cnt_level_reset_quickplay": 0, "cnt_post_score": 2, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 172, "dayofweek": 5}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.05283866309729553, 0.9471613369027044]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.9471613369027044, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 2.238738783519878e-05, "cnt_level_end_quickplay": 3.452685009190937e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -2.054560992550414e-05, "cnt_post_score": -5.9932307735710566e-05, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.00013636171337281234, "country": -0.025495482012644954, "dayofweek": 0.0004971062246130531, "julianday": -0.035381784588893316, "language": 0.017581184333309196, "month": -0.03097946053005256, "operating_system": 0.016375820954302345, "user_pseudo_id": 0.02463218063673478}, "approximationError": 0.020648007798675615}]}}
# {"instance": {"user_pseudo_id": "40493DF7E80F9562EB2A1851A0A72566", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 3, "cnt_level_start_quickplay": 1, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 9, "julianday": 270, "dayofweek": 5}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["1"], "churned_probs": [0.8489218334399561, 0.1510781665600439]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.8489218334399561, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 2.857446373219774e-05, "cnt_post_score": 5.551115123125783e-18, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": 0.00042927945966991646, "country": 0.05855832610587103, "dayofweek": -0.001385889940568439, "julianday": 0.31980590257988606, "language": -0.035510372922593784, "month": 0.23191631531400433, "operating_system": -0.04214772235742546, "user_pseudo_id": 0.2973191180158231}, "approximationError": 0.0180125339726603}]}}
# {"instance": {"user_pseudo_id": "C83B5F6B4BC4680D9E627AD2BDD49E2A", "country": "Canada", "operating_system": "IOS", "language": "en-ca", "cnt_user_engagement": 17, "cnt_level_start_quickplay": 1, "cnt_level_end_quickplay": 1, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 4, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 7, "julianday": 196, "dayofweek": 1}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.1733170412132096, 0.8266829587867904]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.8266829587867903, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": -2.2204460492503132e-17, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 3.0492320294261964e-05, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -2.4174613770022724e-05, "cnt_post_score": -0.0002462181076442915, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.0009019891024839132, "country": -0.04275943376744769, "dayofweek": 0.00017134960668105937, "julianday": -0.11440757206525995, "language": 0.04081669849564684, "month": -0.07037042179176585, "operating_system": 0.03428253053409709, "user_pseudo_id": 0.0}, "approximationError": 0.020662175805018498}]}}
# {"instance": {"user_pseudo_id": "EF67013619BBFA24CAB60C7E25C04C3B", "country": "United Kingdom", "operating_system": "ANDROID", "language": "en-gb", "cnt_user_engagement": 22, "cnt_level_start_quickplay": 5, "cnt_level_end_quickplay": 3, "cnt_level_complete_quickplay": 3, "cnt_level_reset_quickplay": 0, "cnt_post_score": 4, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 7, "julianday": 196, "dayofweek": 1}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["1"], "churned_probs": [0.7927912705690293, 0.20720872943097068]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.7927912705690293, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": -0.00015870015565422406, "cnt_level_end_quickplay": -0.00017429341983014602, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.00015291015052668332, "cnt_post_score": 0.0003048495433321238, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": 0.0034974995465290996, "country": 0.04810686883326838, "dayofweek": -0.00031111192311410326, "julianday": 0.25040971428277037, "language": -0.04090351734601179, "month": 0.1777897384902207, "operating_system": -0.045207587887666954, "user_pseudo_id": 0.37937659773310195}, "approximationError": 0.01680075987144874}]}}
# {"instance": {"user_pseudo_id": "45116F98E0EE54636FE629BA54228131", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 3, "cnt_level_start_quickplay": 1, "cnt_level_end_quickplay": 0, "cnt_level_complete_quickplay": 0, "cnt_level_reset_quickplay": 0, "cnt_post_score": 0, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 6, "julianday": 177, "dayofweek": 3}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["0"], "churned_probs": [0.14162908723003703, 0.858370912769963]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.9800916972784428, "instanceOutputValue": 0.858370912769963, "outputIndex": [1], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": 0.0, "cnt_level_end_quickplay": 0.0, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": -2.0773508183546953e-05, "cnt_post_score": 0.0, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": -0.00014507073750185117, "country": -0.03963015452553305, "dayofweek": 0.0004789017910175941, "julianday": -0.09019512414036734, "language": 0.0316602981621769, "month": -0.05412049958782757, "operating_system": 0.03025163803773907, "user_pseudo_id": 0.0}, "approximationError": 0.020067675913409497}]}}
# {"instance": {"user_pseudo_id": "CA7B71FEB82B214C5F8DB4E020B3811D", "country": "United States", "operating_system": "IOS", "language": "en-us", "cnt_user_engagement": 34, "cnt_level_start_quickplay": 12, "cnt_level_end_quickplay": 11, "cnt_level_complete_quickplay": 4, "cnt_level_reset_quickplay": 0, "cnt_post_score": 4, "cnt_spend_virtual_currency": 0, "cnt_ad_reward": 0, "cnt_challenge_a_friend": 0, "cnt_completed_5_levels": 0, "cnt_use_extra_steps": 0, "month": 9, "julianday": 256, "dayofweek": 5}, "prediction": {"churned_values": ["1", "0"], "predicted_churned": ["1"], "churned_probs": [0.8452946723130675, 0.15470532768693246]}, "explanation": {"attributions": [{"outputName": "churned_probs", "baselineOutputValue": 0.019908302721557195, "instanceOutputValue": 0.8452946723130675, "outputIndex": [0], "featureAttributions": {"cnt_ad_reward": 0.0, "cnt_challenge_a_friend": 0.0, "cnt_completed_5_levels": 0.0, "cnt_level_complete_quickplay": -0.00020545710903188894, "cnt_level_end_quickplay": -0.0006150099770041758, "cnt_level_reset_quickplay": 0.0, "cnt_level_start_quickplay": 0.00034736696246190634, "cnt_post_score": 0.000295320503800707, "cnt_spend_virtual_currency": 0.0, "cnt_use_extra_steps": 0.0, "cnt_user_engagement": 0.004942720503257744, "country": 0.059212072634624045, "dayofweek": -0.0014093904345481058, "julianday": 0.30310123637049113, "language": -0.0358014494354343, "month": 0.23360898249674134, "operating_system": -0.042570026348613045, "user_pseudo_id": 0.30448000342476494}, "approximationError": 0.01823207261918536}]}}
